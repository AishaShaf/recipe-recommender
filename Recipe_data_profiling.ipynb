# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Set the display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

recipes_df = pd.read_csv('recipes_w_search_terms.csv')

# Profiling using pandas-profiling

profile = ProfileReport(recipes_df)
profile.to_file("data_profile_report.html")
# Out:
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_23410/2033111197.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# /opt/homebrew/lib/python3.11/site-packages/ydata_profiling/visualisation/utils.py:73: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
