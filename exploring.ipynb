# %%
import pandas as pd

# %%
dataframe = pd.read_csv(
    r"C:\Users\k.ritscher\Desktop\Bootcamp\Final_Project\archive\recipes_w_search_terms.csv"
)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
dataframe.head(1)
# Out:
#       id                         name  \
# 0  96313  Grilled Garlic Cheese Grits
#
#                                                                                                                                                                                                                                                                                                      description  \
# 0  We love grits, this is another good way to serve them. A great alternative to a baked potato when served with grilled steak or chicken. I belive this recipe could be made with instant grits.The 2 1/2 hours for refrigeration is not include in time. The recipe comes from Tast of Home's Light and Tasty.
#
#                                                            ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', 'garlic', 'olive oil']
#
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494963 entries, 0 to 494962
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   494963 non-null  int64
#  1   name                 494963 non-null  object
#  2   description          485362 non-null  object
#  3   ingredients          494963 non-null  object
#  4   ingredients_raw_str  494963 non-null  object
#  5   serving_size         494963 non-null  object
#  6   servings             494963 non-null  int64
#  7   steps                494963 non-null  object
#  8   tags                 494963 non-null  object
#  9   search_terms         494963 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 37.8+ MB

# %%
dataframe.tail()

# %%
number_rows = dataframe.shape[0]
number_rows
# Out:
# 494963

# %%
number_null_values_total = dataframe.isna().sum().sum()
number_null_values_total
# Out:
# 9601

# %%
null_values_per_column = dataframe.isna().sum()
null_values_per_column
# Out:
# id                        0
# name                      0
# description            9601
# ingredients               0
# ingredients_raw_str       0
# serving_size              0
# servings                  0
# steps                     0
# tags                      0
# search_terms              0
# dtype: int64

# %%
name_first_column = dataframe.columns[0]

Null_values_first_column = dataframe.iloc[:, 0].isnull().sum()

# Output of column names and values
print(f"Column name: {name_first_column}")
print(f"Null Values:\n{Null_values_first_column}")
# Out:
# Column name: id
# Null Values:
# 0

# %%
name_second_column = dataframe.columns[1]

Null_values_second_column = dataframe.iloc[:, 1].isnull().sum()

# Output of column names and values
print(f"Column name: {name_second_column}")
print(f"Null Values:\n{Null_values_second_column}")
# Out:
# Column name: name
# Null Values:
# 0

# %%
dataframe.shape
# Out:
# (494963, 10)

# %%
# no complete duplicates
dataframe.duplicated().sum()
# Out:
# 0

# %%
dataframe["search_terms"].duplicated().sum()
# Out:
# 440615

# %%
# amount of the duplicates we might get rid off
dataframe[["name", "description", "ingredients"]].duplicated().sum()
# Out:
# 186

# %%
# have a look into a sample of that duplicates
duplicate = dataframe[
    dataframe.duplicated(subset=["name", "ingredients", "description"])
]
duplicate.head(1)
# Out:
#            id                        name  \
# 61154  126158  Rick's Vegetable Beef Soup
#
#                                                                                                                                                        description  \
# 61154  This is my version of a basic beef and vegetable soup. I've also done this in a crockpot starting it before going to work and ready to eat when I get home.
#
#                                                                                                                                                                          ingredients  \
# 61154  ['beef stew meat', 'carrots', 'potatoes', 'frozen corn', 'onion', 'beef bouillon', 'bay leaf', 'diced tomatoes', 'green beans', 'water', 'salt', 'fresh ground black pepper']
#
# ...

# %%
# compare the datapoints by spot check,which have the same name, ingredients and description to see if its the same recipeor not
dataframe[dataframe["name"] == "Rick's Vegetable Beef Soup"]
# conclusion: 7 recipes checked and all "twins" show the same recipe
# twins can be deleated in the "Recipe-data-cleaning" - file
# Out:
#            id                        name  \
# 21234  126442  Rick's Vegetable Beef Soup
# 61154  126158  Rick's Vegetable Beef Soup
#
#                                                                                                                                                        description  \
# 21234  This is my version of a basic beef and vegetable soup. I've also done this in a crockpot starting it before going to work and ready to eat when I get home.
# 61154  This is my version of a basic beef and vegetable soup. I've also done this in a crockpot starting it before going to work and ready to eat when I get home.
#
#                                                                                                                                                                          ingredients  \
# ...

# %%
dataframe[
    dataframe["description"].str.contains(
        "Here's another recipe that no one on this web site seems to have heard of",
        na=False,
    )
]
# Out:
#            id                                             name  \
# 61382  127418                          Verenika With Ham Gravy
# 63909  139981  Verenika With Ham Gravy (Cheese Filled Noodles)
#
#                                                                                                                                                                      description  \
# 61382  Here's another recipe that no one on this web site seems to have heard of, but I'm sure probably know another name for it.  I think it's delicious!  Hope you like it!!:)
# 63909  Here's another recipe that no one on this web site seems to have heard of, but I'm sure probably know another name for it.  I think it's delicious!  Hope you like it!!:)
#
#                                                                                                                                                                                                                                       ingredients  \
# ...

# %%
dataframe["ingredients"].str.lower().duplicated().sum()
# Out:
# 5099

# %%
anzahl_vorkommen = (
    dataframe.groupby(dataframe["name"].str.lower()).size().reset_index(name="Anzahl")
)

# shows the recipes names that we have more than once
ergebnis_dataframe = anzahl_vorkommen[anzahl_vorkommen["Anzahl"] > 1]

print(ergebnis_dataframe)
# Out:
#                                                                     name  \
# 169                                   $250 chocolate chip cookies recipe
# 637                                             &quot;fronch&quot; toast
# 1255                                                                 ---
# 1260                                                        ------------
# 1261                                                      --------------
# 1262                                                    ----------------
# 1264                                                 -------------------
# 1266                                              ----------------------
# 1352                                                     1-2-3 jambalaya
# 1365                                                        1-2-3-4 cake
# 1453                                          10 minute szechuan chicken
# 1491                                             100 % whole wheat bread
# ...

# %%
ergebnis_dataframe["Anzahl"].sum()
# Out:
# 114861
