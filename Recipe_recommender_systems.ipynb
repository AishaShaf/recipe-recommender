# %% [markdown]
# # Content-based recipe recommender system using the TF-IDF (Term Frequency-Inverse Document Frequency) technique
# Building a Recipe Recommender System involves using techniques such as collaborative filtering, content-based filtering, or hybrid methods. Let's explore a simple content-based filtering approach where recommendations are made based on the content of recipes and user preferences.
#
# Here's a basic example using TF-IDF (Term Frequency-Inverse Document Frequency) to represent the recipes and cosine similarity to find similar recipes. For demonstration purposes, let's consider the 'tags' and 'ingredients' columns for content-based recommendations:

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Load your dataset
recipes_df = pd.read_csv('recipes_w_search_terms.csv')
recipes_df_short = recipes_df.head(500)

# Combine relevant text features (tags, ingredients, cuisine, difficulty level, prep time)
recipes_df_short['content'] = (
    recipes_df_short['tags'] + ' ' +
    recipes_df_short['ingredients'].apply(', '.join) + ' ' +
    recipes_df_short['steps'].astype(str) + ' ' +
    recipes_df_short['description'].astype(str) + ' ' +
    recipes_df_short['search_terms'].astype(str)
)

# Initialize the TF-IDF vectorizer
print("Fitting TF-IDF vectorizer...")
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the TF-IDF matrix
print("Transforming TF-IDF matrix...")
tfidf_matrix = tfidf_vectorizer.fit_transform(recipes_df_short['content'])

# Calculate cosine similarity between recipes
print("Calculating cosine similarity...")
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to get recipe recommendations
def get_recommendations(recipe_name, cosine_sim=cosine_sim):
    idx = recipes_df.index[recipes_df['name'] == recipe_name].tolist()[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get the top 11 similar recipes (excluding itself)
    recipe_indices = [score[0] for score in sim_scores]
    return recipes_df['name'].iloc[recipe_indices]

# Example: Get recommendations for a specific recipe
recipe_name = 'Grilled Garlic Cheese Grits'
print(f"Getting recommendations for '{recipe_name}'...")
recommendations = get_recommendations(recipe_name)

print(f"Recommendations for '{recipe_name}':")
print(recommendations)
# Out:
# Fitting TF-IDF vectorizer...
# Transforming TF-IDF matrix...
# Calculating cosine similarity...
# Getting recommendations for 'Grilled Garlic Cheese Grits'...
# Recommendations for 'Grilled Garlic Cheese Grits':
# 348                Tomato and Mushroom Omelette
# 233                     Sweet and Tangy Chicken
# 172                  Buttery Apples and Cabbage
# 418                       Butternut Squash Soup
# 8                           Potato-Crab Chowder
# 130             Quick &quot;beef&quot; Stir Fry
# 105                   Italian Chicken and Pasta
# 126    Hamburger-Vegetable Soup With Tortellini
# 306                             Orange Lemonade
# 168                  Chicken Breasts With Herbs
# Name: name, dtype: object
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_23482/328791724.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = (

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Load your dataset
recipes_df = pd.read_csv('recipes_w_search_terms.csv')
recipes_df_short = recipes_df.head(500)

# Combine relevant text features
recipes_df_short['content'] = (
    recipes_df_short['tags'] + ' ' +
    recipes_df_short['ingredients'].apply(', '.join) + ' ' +
    recipes_df_short['steps'].astype(str) + ' ' +
    recipes_df_short['description'].astype(str) + ' ' +
    recipes_df_short['search_terms'].astype(str)
)

# Preprocess text data
recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example

# Initialize the TF-IDF vectorizer with adjusted parameters
tfidf_vectorizer = TfidfVectorizer(stop_words='english', min_df=0.1, max_df=0.9)

# Fit and transform the TF-IDF matrix
tfidf_matrix = tfidf_vectorizer.fit_transform(recipes_df_short['content'])

# Calculate cosine similarity between recipes
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to get recipe recommendations
def get_recommendations(recipe_name, cosine_sim=cosine_sim):
    idx = recipes_df.index[recipes_df['name'] == recipe_name].tolist()[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get the top 11 similar recipes (excluding itself)
    recipe_indices = [score[0] for score in sim_scores]
    return recipes_df.iloc[recipe_indices][['name', 'description', 'ingredients', 'steps', 'tags', 'search_terms']]

# Example: Get recommendations for a specific recipe
recipe_name = 'Grilled Garlic Cheese Grits'
print(f"Getting recommendations for '{recipe_name}'...")

# Get the recommendations DataFrame
recommendations_df = get_recommendations(recipe_name)

# Print the result in the specified format
print(f"\nRecipe: {recipe_name}")
print("Recommended Recipes list:")
recommendations_df
# Out:
# Getting recommendations for 'Grilled Garlic Cheese Grits'...
#
# Recipe: Grilled Garlic Cheese Grits
# Recommended Recipes list:
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_23482/1496838907.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = (
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_23482/1496838907.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example
#                                          name  \
# 33           Pinto Bean Soup With Fresh Salsa
# 279        Pumpkin Soup (Served in the Shell)
# 44                         Kickin' Shrimp Dip
# 348              Tomato and Mushroom Omelette
# 304                     Aunt Paulette's Chili
# 154                       Cucumber Yogurt Dip
# 119            Garden Fresh Eggplant Parmesan
# 126  Hamburger-Vegetable Soup With Tortellini
# 418                     Butternut Squash Soup
# 135                            Broccoli Salad
#
#                                            description  \
# 33   Despite its creamy taste, this simply prepared...
# 279  Great autumm recipe, served in the pumpkin she...
# 44   I've tried a lot of shrimp dip recipes, and I ...
# 348  Makes a hearty breakfast or brunch for one, or...
# 304  This is a recipe from my husband's aunt and is...
# 154  I can not get enough of this recipe for this c...
# 119  This year I finally mastered the art of growin...
# 126           Easy, tasty, and left-overs freeze well.
# 418  This basic soup recipe came from Good Things U...
# 135  This is s treat! Great salad that's pretty hea...
#
#                                            ingredients  \
# 33   ['dried pinto beans', 'water', 'vegetable oil'...
# 279  ['pumpkin', 'unsalted butter', 'onion', 'carro...
# 44   ['cream cheese', 'sour cream', 'old bay season...
# 348  ['eggs', 'potato', 'cheddar cheese', 'dried ch...
# 304  ['ground beef', 'onion', 'garlic clove', 'toma...
# 154  ['plain yogurt', 'lemon%2c juice of', 'garlic ...
# 119  ['eggplants', 'flour', 'egg', 'water', 'parmes...
# 126  ['lean ground beef', 'yellow onion', 'vegetabl...
# 418  ['water', 'chicken bouillon cubes', 'butternut...
# 135  ['broccoli', 'avocado', 'olive oil', 'lemon ju...
#
#                                                  steps  \
# 33   ['Sort through the beans and discard any missh...
# 279  ['Slice off stem of pumpkin, 2-1/2 inches from...
# 44   ['Mix together, adjusting seasonings to taste....
# 348  ['Whisk eggs in a bowl and stir in potato, che...
# 304  ['Brown burger with onion and garlic. Drain fa...
# 154  ['to drain the yogurt, line a mesh colandar wi...
# 119  ['I slice my eggplants the night before (into ...
# 126  ['In a large soup pot over medium heat, brown ...
# 418  ['Combine water, chicken boullion cubes and sq...
# 135  ['Cut broccoli into bite size pieces.', 'Steam...
#
#                                                   tags  \
# 33   ['time-to-make', 'course', 'main-ingredient', ...
# 279  ['time-to-make', 'course', 'main-ingredient', ...
# 44   ['time-to-make', 'course', 'main-ingredient', ...
# 348  ['15-minutes-or-less', 'time-to-make', 'course...
# 304  ['60-minutes-or-less', 'time-to-make', 'course...
# 154  ['time-to-make', 'course', 'cuisine', 'prepara...
# 119  ['weeknight', '60-minutes-or-less', 'time-to-m...
# 126  ['time-to-make', 'course', 'main-ingredient', ...
# 418  ['60-minutes-or-less', 'time-to-make', 'course...
# 135  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                           search_terms
# 33   {'low-calorie', 'low-sodium', 'low-carb', 'mex...
# 279  {'low-calorie', 'soup', 'low-sodium', 'low-carb'}
# 44   {'low-calorie', 'low-sodium', 'low-carb', 'app...
# 348  {'low-sodium', 'low-calorie', 'vegetarian', 'l...
# 304  {'low-calorie', 'dinner', 'low-sodium', 'low-c...
# 154  {'low-sodium', 'low-calorie', 'vegetarian', 'l...
# 119  {'low-calorie', 'vegetarian', 'italian', 'low-...
# 126      {'dinner', 'low-calorie', 'low-carb', 'soup'}
# 418     {'low-fat', 'low-calorie', 'low-carb', 'soup'}
# 135  {'low-calorie', 'low-sodium', 'vegetarian', 's...

# %% [markdown]
# ## Hybrid recommendation model: TF-IDF and cosine similarity for content-based filtering and item-item collaborative filtering

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Load your dataset
recipes_df = pd.read_csv('recipes_w_search_terms.csv')
recipes_df_short = recipes_df.head(500)

# Combine relevant text features
recipes_df_short['content'] = (
    recipes_df_short['tags'] + ' ' +
    recipes_df_short['ingredients'].apply(', '.join) + ' ' +
    recipes_df_short['steps'].astype(str) + ' ' +
    recipes_df_short['description'].astype(str) + ' ' +
    recipes_df_short['search_terms'].astype(str)
)

# Preprocess text data
recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example

# Initialize the TF-IDF vectorizer with adjusted parameters
tfidf_vectorizer = TfidfVectorizer(stop_words='english', min_df=0.1, max_df=0.9)

# Fit and transform the TF-IDF matrix
tfidf_matrix = tfidf_vectorizer.fit_transform(recipes_df_short['content'])

# Calculate cosine similarity between recipes for content-based filtering
cosine_sim_content = linear_kernel(tfidf_matrix, tfidf_matrix)

# Item-Item Collaborative Filtering (item-based similarity)
item_item_sim = cosine_sim_content.T

# Function to get hybrid recipe recommendations
def get_hybrid_recommendations(recipe_name, item_item_sim, recipes_df):
    idx = recipes_df.index[recipes_df['name'] == recipe_name].tolist()[0]

    # Get item-item similarity scores for the given recipe
    item_sim_scores = list(enumerate(item_item_sim[idx]))
    item_sim_scores = sorted(item_sim_scores, key=lambda x: x[1], reverse=True)
    item_sim_scores = item_sim_scores[1:11]  # Get top 10 similar recipes

    # Get top 10 recommended recipes
    recommended_recipes = recipes_df.iloc[[score[0] for score in item_sim_scores[:10]]][['name', 'description', 'ingredients', 'steps', 'tags', 'search_terms']]

    return recommended_recipes

# Example: Get hybrid recommendations for a specific recipe
recipe_name = 'Cucumber Yogurt Dip'
print(f"Getting hybrid recommendations for '{recipe_name}'...")

# Get the hybrid recommendations DataFrame
hybrid_recommendations_df = get_hybrid_recommendations(recipe_name, item_item_sim, recipes_df_short)

# Print the result in the specified format
print(f"\nRecipe: {recipe_name}")
print("Hybrid Recommended Recipes list:")
hybrid_recommendations_df
# Out:
# Getting hybrid recommendations for 'Cucumber Yogurt Dip'...
#
# Recipe: Cucumber Yogurt Dip
# Hybrid Recommended Recipes list:
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_28069/437495372.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = (
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_28069/437495372.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example
#                                name  \
# 135                  Broccoli Salad
# 426            Banana-Rama Mocktail
# 304           Aunt Paulette's Chili
# 243  Cilantro Sparkling Wine Cooler
# 52        Beat and Bake Sponge Cake
# 223                Strawberry Swirl
# 307               The Mad Hungarian
# 44               Kickin' Shrimp Dip
# 97            Caramel Apple Nibbles
# 311     Butternut Squash Apple Soup
#
#                                            description  \
# 135  This is s treat! Great salad that's pretty hea...
# 426                         Found at the lcbo.ca site.
# 304  This is a recipe from my husband's aunt and is...
# 243  The perfect anecdote to a scorching summer's d...
# 52   I have tried other sponge cake recipes and the...
# 223                        Great for afternoon energy!
# 307  Guess someone messed with his goulash!\n\nCour...
# 44   I've tried a lot of shrimp dip recipes, and I ...
# 97   Amazingly simple and who doesn't like a carame...
# 311  From Simply Recipes. I bet this would freeze o...
#
#                                            ingredients  \
# 135  ['broccoli', 'avocado', 'olive oil', 'lemon ju...
# 426  ['ice', 'banana', 'strawberries', 'pineapple j...
# 304  ['ground beef', 'onion', 'garlic clove', 'toma...
# 243  ['fresh cilantro', 'sparkling white wine', 'li...
# 52   ['margarine', 'sugar', 'flour', 'baking powder...
# 223  ['strawberry', 'low-fat milk', 'sugar', 'vanil...
# 307                               ['rum', 'root beer']
# 44   ['cream cheese', 'sour cream', 'old bay season...
# 97                ['caramel sauce', 'apple', 'pecans']
# 311  ['yellow onion', 'celery rib', 'carrot', 'butt...
#
#                                                  steps  \
# 135  ['Cut broccoli into bite size pieces.', 'Steam...
# 426  ['In a blender, combine all ingredients. Blend...
# 304  ['Brown burger with onion and garlic. Drain fa...
# 243  ['Tie the cilantro to secure in place before b...
# 52   ['Heat the oven to 180 deg Celsius.', 'Grease ...
# 223  ['Clean berries.', 'Combine all ingredients in...
# 307  ['Pour rum over ice in a frosted beer mug.', '...
# 44   ['Mix together, adjusting seasonings to taste....
# 97   ['I like to heat the caramel just a bit in the...
# 311  ['Combine butter, onion, celery, and carrot in...
#
#                                                   tags  \
# 135  ['30-minutes-or-less', 'time-to-make', 'course...
# 426  ['15-minutes-or-less', 'time-to-make', 'course...
# 304  ['60-minutes-or-less', 'time-to-make', 'course...
# 243  ['15-minutes-or-less', 'time-to-make', 'course...
# 52   ['60-minutes-or-less', 'time-to-make', 'course...
# 223  ['15-minutes-or-less', 'time-to-make', 'course...
# 307  ['15-minutes-or-less', 'time-to-make', 'course...
# 44   ['time-to-make', 'course', 'main-ingredient', ...
# 97   ['15-minutes-or-less', 'time-to-make', 'course...
# 311  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                           search_terms
# 135  {'low-calorie', 'low-sodium', 'vegetarian', 's...
# 426  {'low-calorie', 'low-sodium', 'vegetarian', 'l...
# 304  {'low-calorie', 'dinner', 'low-sodium', 'low-c...
# 243  {'low-sodium', 'low-calorie', 'vegetarian', 'i...
# 52   {'low-calorie', 'low-sodium', 'dessert', 'low-...
# 223  {'low-calorie', 'low-sodium', 'vegetarian', 'h...
# 307  {'low-calorie', 'low-sodium', 'healthy', 'low-...
# 44   {'low-calorie', 'low-sodium', 'low-carb', 'app...
# 97   {'low-calorie', 'low-sodium', 'low-carb', 'app...
# 311  {'low-calorie', 'low-sodium', 'healthy', 'low-...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from fuzzywuzzy import process

# Load your dataset
recipes_df = pd.read_csv('recipes_w_search_terms.csv')
recipes_df_short = recipes_df.head(200)

# Combine relevant text features
recipes_df_short['content'] = (
    recipes_df_short['tags'] + ' ' +
    recipes_df_short['ingredients'].apply(', '.join) + ' ' +
    recipes_df_short['steps'].astype(str) + ' ' +
    recipes_df_short['description'].astype(str) + ' ' +
    recipes_df_short['search_terms'].astype(str)
)

# Preprocess text data
recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example

# Initialize the TF-IDF vectorizer with adjusted parameters
tfidf_vectorizer = TfidfVectorizer(stop_words='english', min_df=0.1, max_df=0.9)

# Fit and transform the TF-IDF matrix
tfidf_matrix = tfidf_vectorizer.fit_transform(recipes_df_short['content'])

# Calculate cosine similarity between recipes for content-based filtering
cosine_sim_content = linear_kernel(tfidf_matrix, tfidf_matrix)

# Item-Item Collaborative Filtering (item-based similarity)
item_item_sim = cosine_sim_content.T

# Function to get the closest matching recipe name based on user input
def get_closest_recipe_name(user_input, recipe_names):
    match, score = process.extractOne(user_input, recipe_names.tolist())
    return match, score

# Function to get hybrid recipe recommendations based on user input
def get_hybrid_recommendations_by_name(user_input, item_item_sim, recipes_df):
    # Find the closest matching recipe name in the dataset
    closest_recipe_name, score = get_closest_recipe_name(user_input, recipes_df['name'])

    # Get recommendations for the closest matching recipe name
    hybrid_recommendations_df = get_hybrid_recommendations(closest_recipe_name, item_item_sim, recipes_df)

    return hybrid_recommendations_df

# Function to get hybrid recipe recommendations
def get_hybrid_recommendations(recipe_name, item_item_sim, recipes_df):
    idx = recipes_df.index[recipes_df['name'] == recipe_name].tolist()[0]

    # Get item-item similarity scores for the given recipe
    item_sim_scores = list(enumerate(item_item_sim[idx]))
    item_sim_scores = sorted(item_sim_scores, key=lambda x: x[1], reverse=True)
    item_sim_scores = item_sim_scores[1:11]  # Get top 10 similar recipes

    # Get top 10 recommended recipes
    recommended_recipes = recipes_df.iloc[[score[0] for score in item_sim_scores[:10]]][['name', 'description', 'ingredients', 'steps', 'tags', 'search_terms']]

    return recommended_recipes

# Example: Get hybrid recommendations for a user-inputted recipe name
user_input_recipe_name = 'chicken sandwich'
print(f"Getting hybrid recommendations for '{user_input_recipe_name}'...")

# Get the hybrid recommendations DataFrame based on user input
hybrid_recommendations_by_name_df = get_hybrid_recommendations_by_name(user_input_recipe_name, item_item_sim, recipes_df_short)

# Print the result in the specified format
print(f"\nUser Input Recipe Name: {user_input_recipe_name}")
print("Hybrid Recommended Recipes list:")
print(hybrid_recommendations_by_name_df[['name', 'description', 'ingredients', 'steps', 'tags', 'search_terms']])
# Out:
# Getting hybrid recommendations for 'chicken sandwich'...
#
# User Input Recipe Name: chicken sandwich
# Hybrid Recommended Recipes list:
#                                               name  \
# 158        Spinach and Rice Stuffed Chicken Breast
# 105                      Italian Chicken and Pasta
# 199  Sun-Dried Tomato Chicken Pesto Couscous Salad
# 73                                         Biryani
# 147               Chicken in Orange-Riesling Sauce
# 110         Chicken Thighs With Lemon &amp; Garlic
# 168                     Chicken Breasts With Herbs
# 50                      Chicken Parm Meatball Subs
# 15           Santa Fe-Tastic Chicken Tortilla Soup
# 146                            Sweet Asian Chicken
#
#                                            description  \
# 158  A VERY good, and VERY easy dinner that's guara...
# 105  I love italian food but I am a diabetic, so I ...
# 199  This is such a quick recipe to make and has a ...
# 73                                        Delhi, India
# 147              In ‘ Williams-Sonoma: Simple Suppers’
# 110  This is a Mediterranean/Greek recipe. It's ver...
# 168           From Melanie Barnard in BH&G april 2008.
# 50      A great tasting, easy recipe from Rachael Ray.
# 15   This is Rachel Ray's.  It is so awesome, I can...
# 146                                Everyone's favorite
#
#                                            ingredients  \
# 158  ['boneless skinless chicken breasts', 'extra v...
# 105  ['boneless skinless chicken breasts', 'rotini ...
# 199  ['olive oil', 'chicken breasts', 'sun-dried to...
# 73   ['saffron', 'milk', 'hot green chili peppers',...
# 147  ['orange', 'boneless skinless chicken breast h...
# 110  ['chicken stock', 'garlic cloves', 'butter', '...
# 168  ['flat-leaf italian parsley', 'fresh oregano',...
# 50   ['ground chicken', 'seasoning', 'egg', 'parmes...
# 15   ['vegetable oil', 'vegetable oil', 'corn on th...
# 146  ['chicken', 'bourbon', 'soy sauce', 'ginger', ...
#
#                                                  steps  \
# 158  ['Prepare the rice until it is ALMOST done.  T...
# 105  ['preheat oven to 450.', 'Spray pan with oil o...
# 199  ['Bring the water and stock to the boil, add s...
# 73   ['Soak saffron in warm milk for 5 minutes and ...
# 147  ['Finely grate 2 teaspoons orange zest and squ...
# 110  ['Preheat oven to 350°.', 'Bring stock, garlic...
# 168  ['In a bowl, stir together parsley, oregano, l...
# 50   ['Preheat the oven to 425*F.', 'Place the chic...
# 15   ['Heat a grill pan to high and a soup pot to m...
# 146  ['Add bourbon, soy sauce, ginger, garlic, vine...
#
#                                                   tags  \
# 158  ['60-minutes-or-less', 'time-to-make', 'course...
# 105  ['60-minutes-or-less', 'time-to-make', 'course...
# 199  ['30-minutes-or-less', 'time-to-make', 'course...
# 73   ['weeknight', 'time-to-make', 'course', 'main-...
# 147  ['60-minutes-or-less', 'time-to-make', 'course...
# 110  ['60-minutes-or-less', 'time-to-make', 'course...
# 168  ['30-minutes-or-less', 'time-to-make', 'course...
# 50   ['30-minutes-or-less', 'time-to-make', 'course...
# 15   ['60-minutes-or-less', 'time-to-make', 'course...
# 146  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                           search_terms
# 158                              {'dinner', 'chicken'}
# 105  {'diabetic', 'italian', 'pasta', 'dinner', 'ch...
# 199                     {'chicken', 'dinner', 'salad'}
# 73                  {'indian', 'dinner', 'low-sodium'}
# 147                              {'dinner', 'chicken'}
# 110  {'low-sodium', 'greek', 'low-carb', 'dinner', ...
# 168  {'diabetic', 'low-sodium', 'low-carb', 'dinner...
# 50                      {'dinner', 'lunch', 'chicken'}
# 15                                 {'soup', 'chicken'}
# 146       {'dessert', 'dinner', 'low-carb', 'chicken'}
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_28069/2079856449.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = (
# /var/folders/jl/tcgfk4mx3gg3jtw3rcbk08pw0000gp/T/ipykernel_28069/2079856449.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_df_short['content'] = recipes_df_short['content'].apply(lambda x: x.lower())  # Convert to lowercase, for example
